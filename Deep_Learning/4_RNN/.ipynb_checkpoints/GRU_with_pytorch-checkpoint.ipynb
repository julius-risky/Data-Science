# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
import torch
from torch import nn, optim
from jcopdl.callback import Callback, set_config

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Import data

# %%
df = pd.read_csv("data/daily_min_temp.csv", index_col="Date", parse_dates=["Date"])
df.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
df.Temp.plot(figsize=(15,5), color = "b")

# %% [markdown]
# # Dataset Spliting

# %%
ts_train, ts_test = train_test_split(df, test_size=0.2, shuffle = False)
ts_train.shape, ts_test.shape
# Out:
# ((2920, 1), (730, 1))

# %% [markdown]
# # Dataset dan dataloader

# %%
from jcopdl.utils.dataloader import TimeSeriesDataset
from torch.utils.data import DataLoader

# %%
seq_len = 14
bs = 32

train_set = TimeSeriesDataset(ts_train,"Temp", seq_len)
trainloader = DataLoader(train_set, batch_size=bs)

test_set = TimeSeriesDataset(ts_test,"Temp",seq_len)
testloader = DataLoader(test_set, batch_size=bs)
# Out:
# (N, S, F): (208, 14, 1)
# Note: last 7 data excluded
#
# (N, S, F): (52, 14, 1)
# Note: last 1 data excluded

# %% [markdown]
# # Arsitektur dan config

# %%
class LSTM(nn.Module):
    def __init__(self, input_size,output_size, hidden_size, num_layers, dropout):
        super().__init__()
        
        self.rnn = nn.LSTM(input_size, hidden_size, num_layers, dropout = dropout, batch_first =True)
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden):
        x , hidden = self.rnn(x, hidden)
        x = self.fc(x)
        return x, hidden

# %%
config = set_config({
    "input_size": train_set.n_feature,
    "seq_len": train_set.n_seq,
    "output_size":1,
    "hidden_size": 64,
    "num_layers": 2,
    "dropout": 0
})

# %% [markdown]
# # Training Preparation

# %%
model = LSTM(config.input_size, config.output_size, config.hidden_size, config.num_layers, config.dropout).to(device)
criterion = nn.MSELoss(reduce="mean")
optimizer = optim.AdamW(model.parameters(), lr=0.001)
callback = Callback(model, config, outdir="model/lstm")
# Out:
# /home/yulius/miniconda3/envs/jcopdl/lib/python3.7/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# # Training

# %%
from tqdm.auto import tqdm

def loop_fn(mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode == "train":
        model.train()
    elif mode == "test":
        model.eval()
    cost = 0
    for feature, target in tqdm(dataloader, desc=mode.title()):
        feature, target = feature.to(device), target.to(device)
        output, hidden = model(feature, None)
        loss = criterion(output, target)
        
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        
        cost += loss.item() * feature.shape[0]
    cost = cost / len(dataset)
    return cost

# %%
while True:
    train_cost = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
    with torch.no_grad():
        test_cost = loop_fn("test", test_set, testloader, model, criterion, optimizer, device)
    
    # Logging
    callback.log(train_cost, test_cost)

    # Checkpoint
    callback.save_checkpoint()
        
    # Runtime Plotting
    callback.cost_runtime_plotting()
    
    # Early Stopping
    if callback.early_stopping(model, monitor="test_cost"):
        callback.plot_cost()
        break
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     1
# Train_cost  = 137.0089 | Test_cost  = 137.9710 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     2
# Train_cost  = 122.9948 | Test_cost  = 118.2119 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     3
# Train_cost  = 101.9117 | Test_cost  = 95.7414 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     4
# Train_cost  = 81.3223 | Test_cost  = 76.5582 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     5
# Train_cost  = 64.9995 | Test_cost  = 62.9813 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     6
# Train_cost  = 54.1082 | Test_cost  = 54.0235 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     7
# Train_cost  = 46.6718 | Test_cost  = 47.3427 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     8
# Train_cost  = 40.9877 | Test_cost  = 42.0028 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     9
# Train_cost  = 36.4180 | Test_cost  = 37.6015 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    10
# Train_cost  = 32.6691 | Test_cost  = 33.9574 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    11
# Train_cost  = 29.5995 | Test_cost  = 30.9496 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    12
# Train_cost  = 27.0947 | Test_cost  = 28.4717 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    13
# Train_cost  = 25.0589 | Test_cost  = 26.4380 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    14
# Train_cost  = 23.4140 | Test_cost  = 24.7767 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    15
# Train_cost  = 22.0937 | Test_cost  = 23.4266 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    16
# Train_cost  = 21.0415 | Test_cost  = 22.3347 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    17
# Train_cost  = 20.2086 | Test_cost  = 21.4558 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    18
# Train_cost  = 19.5538 | Test_cost  = 20.7510 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    19
# Train_cost  = 19.0418 | Test_cost  = 20.1875 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    20
# Train_cost  = 18.6431 | Test_cost  = 19.7376 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    21
# Train_cost  = 18.3336 | Test_cost  = 19.3785 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    22
# Train_cost  = 18.0931 | Test_cost  = 19.0914 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    23
# Train_cost  = 17.9059 | Test_cost  = 18.8610 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    24
# Train_cost  = 17.7593 | Test_cost  = 18.6753 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    25
# Train_cost  = 17.6434 | Test_cost  = 18.5247 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    26
# Train_cost  = 17.5507 | Test_cost  = 18.4016 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    27
# Train_cost  = 17.4754 | Test_cost  = 18.3001 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    28
# Train_cost  = 17.4133 | Test_cost  = 18.2156 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    29
# Train_cost  = 17.3610 | Test_cost  = 18.1448 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    30
# Train_cost  = 17.3164 | Test_cost  = 18.0846 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    31
# Train_cost  = 17.2776 | Test_cost  = 18.0332 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    32
# Train_cost  = 17.2434 | Test_cost  = 17.9887 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    33
# Train_cost  = 17.2128 | Test_cost  = 17.9500 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    34
# Train_cost  = 17.1854 | Test_cost  = 17.9162 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    35
# Train_cost  = 17.1606 | Test_cost  = 17.8864 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    36
# Train_cost  = 17.1381 | Test_cost  = 17.8599 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    37
# Train_cost  = 17.1175 | Test_cost  = 17.8363 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    38
# Train_cost  = 17.0984 | Test_cost  = 17.8149 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    39
# Train_cost  = 17.0808 | Test_cost  = 17.7955 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    40
# Train_cost  = 17.0645 | Test_cost  = 17.7778 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    41
# Train_cost  = 17.0492 | Test_cost  = 17.7616 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    42
# Train_cost  = 17.0350 | Test_cost  = 17.7466 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    43
# Train_cost  = 17.0216 | Test_cost  = 17.7327 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    44
# Train_cost  = 17.0091 | Test_cost  = 17.7197 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    45
# Train_cost  = 16.9972 | Test_cost  = 17.7075 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    46
# Train_cost  = 16.9861 | Test_cost  = 17.6961 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    47
# Train_cost  = 16.9755 | Test_cost  = 17.6853 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    48
# Train_cost  = 16.9654 | Test_cost  = 17.6751 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    49
# Train_cost  = 16.9559 | Test_cost  = 17.6654 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    50
# Train_cost  = 16.9468 | Test_cost  = 17.6562 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    51
# Train_cost  = 16.9381 | Test_cost  = 17.6475 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    52
# Train_cost  = 16.9298 | Test_cost  = 17.6391 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    53
# Train_cost  = 16.9217 | Test_cost  = 17.6308 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    54
# Train_cost  = 16.9136 | Test_cost  = 17.6225 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    55
# Train_cost  = 16.9058 | Test_cost  = 17.6150 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    56
# Train_cost  = 16.8987 | Test_cost  = 17.6081 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    57
# Train_cost  = 16.8921 | Test_cost  = 17.6015 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    58
# Train_cost  = 16.8855 | Test_cost  = 17.5948 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    59
# Train_cost  = 16.8786 | Test_cost  = 17.5874 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    60
# Train_cost  = 16.8717 | Test_cost  = 17.5812 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    61
# Train_cost  = 16.8658 | Test_cost  = 17.5757 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    62
# Train_cost  = 16.8604 | Test_cost  = 17.5702 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    63
# Train_cost  = 16.8549 | Test_cost  = 17.5647 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    64
# Train_cost  = 16.8484 | Test_cost  = 17.5543 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    65
# Train_cost  = 16.8333 | Test_cost  = 17.5486 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    66
# Train_cost  = 16.8247 | Test_cost  = 17.5378 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    67
# Train_cost  = 16.8134 | Test_cost  = 17.5153 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    68
# Train_cost  = 16.8008 | Test_cost  = 17.5043 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    69
# Train_cost  = 16.7917 | Test_cost  = 17.4961 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    70
# Train_cost  = 16.7838 | Test_cost  = 17.4862 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    71
# Train_cost  = 16.7752 | Test_cost  = 17.4767 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    72
# Train_cost  = 16.7679 | Test_cost  = 17.4694 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    73
# Train_cost  = 16.7604 | Test_cost  = 17.4621 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    74
# Train_cost  = 16.7531 | Test_cost  = 17.4547 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    75
# Train_cost  = 16.7451 | Test_cost  = 17.4462 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    76
# Train_cost  = 16.7304 | Test_cost  = 17.4105 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    77
# Train_cost  = 16.6804 | Test_cost  = 17.3922 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    78
# Train_cost  = 16.6607 | Test_cost  = 17.3486 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    79
# Train_cost  = 16.6272 | Test_cost  = 17.3073 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    80
# Train_cost  = 16.5809 | Test_cost  = 17.2230 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    81
# Train_cost  = 16.4472 | Test_cost  = 16.9875 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    82
# Train_cost  = 16.1216 | Test_cost  = 16.3422 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    83
# Train_cost  = 15.0470 | Test_cost  = 14.4705 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    84
# Train_cost  = 13.3716 | Test_cost  = 13.6642 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    85
# Train_cost  = 12.6407 | Test_cost  = 12.5399 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    86
# Train_cost  = 11.8320 | Test_cost  = 11.6524 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    87
# Train_cost  = 11.0801 | Test_cost  = 11.0193 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    88
# Train_cost  = 10.5658 | Test_cost  = 10.3365 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    89
# Train_cost  = 10.0187 | Test_cost  = 9.8088 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    90
# Train_cost  = 9.5575 | Test_cost  = 9.3417 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    91
# Train_cost  = 9.2280 | Test_cost  = 8.9316 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    92
# Train_cost  = 8.9549 | Test_cost  = 8.5519 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    93
# Train_cost  = 8.6620 | Test_cost  = 8.2565 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    94
# Train_cost  = 8.4101 | Test_cost  = 7.9990 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    95
# Train_cost  = 8.2267 | Test_cost  = 7.7640 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    96
# Train_cost  = 8.0630 | Test_cost  = 7.5631 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    97
# Train_cost  = 7.9066 | Test_cost  = 7.3977 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    98
# Train_cost  = 7.7688 | Test_cost  = 7.2663 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    99
# Train_cost  = 7.6705 | Test_cost  = 7.1028 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   100
# Train_cost  = 7.5599 | Test_cost  = 7.0052 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   101
# Train_cost  = 7.4676 | Test_cost  = 6.9013 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   102
# Train_cost  = 7.3826 | Test_cost  = 6.8070 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   103
# Train_cost  = 7.3111 | Test_cost  = 6.7234 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   104
# Train_cost  = 7.2467 | Test_cost  = 6.6423 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   105
# Train_cost  = 7.1850 | Test_cost  = 6.5765 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   106
# Train_cost  = 7.1324 | Test_cost  = 6.5116 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   107
# Train_cost  = 7.0827 | Test_cost  = 6.4543 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   108
# Train_cost  = 7.0389 | Test_cost  = 6.4008 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   109
# Train_cost  = 6.9975 | Test_cost  = 6.3522 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   110
# Train_cost  = 6.9594 | Test_cost  = 6.3070 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   111
# Train_cost  = 6.9243 | Test_cost  = 6.2654 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   112
# Train_cost  = 6.8917 | Test_cost  = 6.2277 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   113
# Train_cost  = 6.8616 | Test_cost  = 6.1923 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   114
# Train_cost  = 6.8332 | Test_cost  = 6.1600 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   115
# Train_cost  = 6.8067 | Test_cost  = 6.1291 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   116
# Train_cost  = 6.7816 | Test_cost  = 6.1004 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   117
# Train_cost  = 6.7578 | Test_cost  = 6.0731 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   118
# Train_cost  = 6.7352 | Test_cost  = 6.0468 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   119
# Train_cost  = 6.7133 | Test_cost  = 6.0218 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   120
# Train_cost  = 6.6925 | Test_cost  = 5.9975 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   121
# Train_cost  = 6.6721 | Test_cost  = 5.9744 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   122
# Train_cost  = 6.6527 | Test_cost  = 5.9520 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   123
# Train_cost  = 6.6337 | Test_cost  = 5.9307 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   124
# Train_cost  = 6.6155 | Test_cost  = 5.9101 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   125
# Train_cost  = 6.5979 | Test_cost  = 5.8904 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   126
# Train_cost  = 6.5808 | Test_cost  = 5.8714 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   127
# Train_cost  = 6.5641 | Test_cost  = 5.8532 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   128
# Train_cost  = 6.5480 | Test_cost  = 5.8358 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   129
# Train_cost  = 6.5323 | Test_cost  = 5.8192 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   130
# Train_cost  = 6.5171 | Test_cost  = 5.8034 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   131
# Train_cost  = 6.5023 | Test_cost  = 5.7883 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   132
# Train_cost  = 6.4879 | Test_cost  = 5.7740 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   133
# Train_cost  = 6.4738 | Test_cost  = 5.7603 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   134
# Train_cost  = 6.4601 | Test_cost  = 5.7473 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   135
# Train_cost  = 6.4466 | Test_cost  = 5.7347 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   136
# Train_cost  = 6.4334 | Test_cost  = 5.7226 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   137
# Train_cost  = 6.4204 | Test_cost  = 5.7106 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   138
# Train_cost  = 6.4076 | Test_cost  = 5.6989 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   139
# Train_cost  = 6.3948 | Test_cost  = 5.6872 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   140
# Train_cost  = 6.3821 | Test_cost  = 5.6755 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   141
# Train_cost  = 6.3696 | Test_cost  = 5.6636 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   142
# Train_cost  = 6.3571 | Test_cost  = 5.6515 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   143
# Train_cost  = 6.3447 | Test_cost  = 5.6393 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   144
# Train_cost  = 6.3325 | Test_cost  = 5.6269 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   145
# Train_cost  = 6.3205 | Test_cost  = 5.6147 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   146
# Train_cost  = 6.3087 | Test_cost  = 5.6029 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   147
# Train_cost  = 6.2971 | Test_cost  = 5.5916 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   148
# Train_cost  = 6.2859 | Test_cost  = 5.5809 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   149
# Train_cost  = 6.2748 | Test_cost  = 5.5710 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   150
# Train_cost  = 6.2640 | Test_cost  = 5.5618 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   151
# Train_cost  = 6.2534 | Test_cost  = 5.5532 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   152
# Train_cost  = 6.2429 | Test_cost  = 5.5453 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   153
# Train_cost  = 6.2326 | Test_cost  = 5.5379 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   154
# Train_cost  = 6.2223 | Test_cost  = 5.5310 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   155
# Train_cost  = 6.2122 | Test_cost  = 5.5244 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   156
# Train_cost  = 6.2023 | Test_cost  = 5.5181 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   157
# Train_cost  = 6.1924 | Test_cost  = 5.5120 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   158
# Train_cost  = 6.1826 | Test_cost  = 5.5061 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   159
# Train_cost  = 6.1729 | Test_cost  = 5.5003 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   160
# Train_cost  = 6.1632 | Test_cost  = 5.4948 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   161
# Train_cost  = 6.1536 | Test_cost  = 5.4894 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   162
# Train_cost  = 6.1441 | Test_cost  = 5.4841 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   163
# Train_cost  = 6.1346 | Test_cost  = 5.4790 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   164
# Train_cost  = 6.1252 | Test_cost  = 5.4739 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   165
# Train_cost  = 6.1157 | Test_cost  = 5.4690 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   166
# Train_cost  = 6.1064 | Test_cost  = 5.4642 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   167
# Train_cost  = 6.0970 | Test_cost  = 5.4595 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   168
# Train_cost  = 6.0877 | Test_cost  = 5.4550 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   169
# Train_cost  = 6.0784 | Test_cost  = 5.4507 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   170
# Train_cost  = 6.0692 | Test_cost  = 5.4466 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   171
# Train_cost  = 6.0601 | Test_cost  = 5.4428 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   172
# Train_cost  = 6.0510 | Test_cost  = 5.4392 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   173
# Train_cost  = 6.0420 | Test_cost  = 5.4359 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   174
# Train_cost  = 6.0330 | Test_cost  = 5.4330 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   175
# Train_cost  = 6.0240 | Test_cost  = 5.4303 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   176
# Train_cost  = 6.0145 | Test_cost  = 5.4262 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   177
# Train_cost  = 6.0036 | Test_cost  = 5.4211 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   178
# Train_cost  = 5.9934 | Test_cost  = 5.4206 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   179
# Train_cost  = 5.9842 | Test_cost  = 5.4178 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   180
# Train_cost  = 5.9751 | Test_cost  = 5.4130 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   181
# Train_cost  = 5.9638 | Test_cost  = 5.4112 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   182
# Train_cost  = 5.9538 | Test_cost  = 5.4112 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   183
# Train_cost  = 5.9451 | Test_cost  = 5.4115 |
# ==> EarlyStop patience =  1 | Best test_cost: 5.4112
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   184
# Train_cost  = 5.9346 | Test_cost  = 5.4097 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   185
# Train_cost  = 5.9232 | Test_cost  = 5.4087 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   186
# Train_cost  = 5.9139 | Test_cost  = 5.4120 |
# ==> EarlyStop patience =  1 | Best test_cost: 5.4087
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   187
# Train_cost  = 5.9050 | Test_cost  = 5.4142 |
# ==> EarlyStop patience =  2 | Best test_cost: 5.4087
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   188
# Train_cost  = 5.8951 | Test_cost  = 5.4138 |
# ==> EarlyStop patience =  3 | Best test_cost: 5.4087
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   189
# Train_cost  = 5.8852 | Test_cost  = 5.4152 |
# ==> EarlyStop patience =  4 | Best test_cost: 5.4087
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   190
# Train_cost  = 5.8760 | Test_cost  = 5.4206 |
# ==> EarlyStop patience =  5 | Best test_cost: 5.4087
# ==> Execute Early Stopping at epoch: 190 | Best test_cost: 5.4087
# ==> Best model is saved at model/lstm

# %% [markdown]
# # Sanity Check

# %%
from luwiji.rnn import illustration

# %%
illustration.forecast

# %%
from utils import data4pred, pred4pred

# %%
train_forecast_set =TimeSeriesDataset(ts_train,"Temp",1)
trainforecastloader = DataLoader(train_forecast_set)
test_forecast_set =TimeSeriesDataset(ts_test,"Temp",1)
testforecastloader = DataLoader(test_forecast_set)
# Out:
# (N, S, F): (2919, 1, 1)
# Note: last 0 data excluded
#
# (N, S, F): (729, 1, 1)
# Note: last 0 data excluded

# %% [markdown]
# # Visualization

# %%
#data 4 pred
plt.figure(figsize=(15,10))

plt.subplot(211)
data4pred(model,train_forecast_set, trainforecastloader, device)
plt.title("Train")

plt.subplot(212)
data4pred(model,test_forecast_set, testforecastloader, device)
plt.title("Test")
# Out:
# Text(0.5, 1.0, 'Test')

# %%
#pred 4 pred
plt.figure(figsize=(15,10))
pred4pred(model,test_forecast_set, testforecastloader, device)
plt.title("Test")
# Out:
# Text(0.5, 1.0, 'Test')
