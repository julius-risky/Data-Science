# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
import torch
from torch import nn, optim
from jcopdl.callback import Callback, set_config

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Import data

# %%
df = pd.read_csv("data/daily_min_temp.csv", index_col="Date", parse_dates=["Date"])
df.head()
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8

# %%
df.Temp.plot(figsize=(15,5), color = "b")

# %% [markdown]
# # Dataset Spliting

# %%
ts_train, ts_test = train_test_split(df, test_size=0.2, shuffle = False)
ts_train.shape, ts_test.shape
# Out:
# ((2920, 1), (730, 1))

# %% [markdown]
# # Dataset dan dataloader

# %%
from jcopdl.utils.dataloader import TimeSeriesDataset
from torch.utils.data import DataLoader

# %%
seq_len = 14
bs = 32

train_set = TimeSeriesDataset(ts_train,"Temp", seq_len)
trainloader = DataLoader(train_set, batch_size=bs)

test_set = TimeSeriesDataset(ts_test,"Temp",seq_len)
testloader = DataLoader(test_set, batch_size=bs)
# Out:
# (N, S, F): (208, 14, 1)
# Note: last 7 data excluded
#
# (N, S, F): (52, 14, 1)
# Note: last 1 data excluded

# %% [markdown]
# # Arsitektur dan config

# %%
class GRU(nn.Module):
    def __init__(self, input_size,output_size, hidden_size, num_layers, dropout):
        super().__init__()
        
        self.rnn = nn.GRU(input_size, hidden_size, num_layers, dropout = dropout, batch_first =True)
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden):
        x , hidden = self.rnn(x, hidden)
        x = self.fc(x)
        return x, hidden

# %%
config = set_config({
    "input_size": train_set.n_feature,
    "seq_len": train_set.n_seq,
    "output_size":1,
    "hidden_size": 64,
    "num_layers": 3,
    "dropout": 0
})

# %% [markdown]
# # Training Preparation

# %%
model = GRU(config.input_size, config.output_size, config.hidden_size, config.num_layers, config.dropout).to(device)
criterion = nn.MSELoss(reduce="mean")
optimizer = optim.AdamW(model.parameters(), lr=0.001)
callback = Callback(model, config, outdir="model/gru")
# Out:
# /home/yulius/miniconda3/envs/jcopdl/lib/python3.7/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))

# %% [markdown]
# # Training

# %%
from tqdm.auto import tqdm

def loop_fn(mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode == "train":
        model.train()
    elif mode == "test":
        model.eval()
    cost = 0
    for feature, target in tqdm(dataloader, desc=mode.title()):
        feature, target = feature.to(device), target.to(device)
        output, hidden = model(feature, None)
        loss = criterion(output, target)
        
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        
        cost += loss.item() * feature.shape[0]
    cost = cost / len(dataset)
    return cost

# %%
while True:
    train_cost = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
    with torch.no_grad():
        test_cost = loop_fn("test", test_set, testloader, model, criterion, optimizer, device)
    
    # Logging
    callback.log(train_cost, test_cost)

    # Checkpoint
    callback.save_checkpoint()
        
    # Runtime Plotting
    callback.cost_runtime_plotting()
    
    # Early Stopping
    if callback.early_stopping(model, monitor="test_cost"):
        callback.plot_cost()
        break
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     1
# Train_cost  = 132.6125 | Test_cost  = 125.0422 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     2
# Train_cost  = 106.1953 | Test_cost  = 96.8109 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     3
# Train_cost  = 81.8729 | Test_cost  = 77.4138 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     4
# Train_cost  = 66.5361 | Test_cost  = 65.3872 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     5
# Train_cost  = 56.6281 | Test_cost  = 56.7846 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     6
# Train_cost  = 49.2552 | Test_cost  = 49.9433 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     7
# Train_cost  = 43.2949 | Test_cost  = 44.2467 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     8
# Train_cost  = 38.3273 | Test_cost  = 39.4436 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch     9
# Train_cost  = 34.1667 | Test_cost  = 35.3993 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    10
# Train_cost  = 30.6980 | Test_cost  = 32.0119 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    11
# Train_cost  = 27.8263 | Test_cost  = 29.1913 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    12
# Train_cost  = 25.4658 | Test_cost  = 26.8555 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    13
# Train_cost  = 23.5392 | Test_cost  = 24.9312 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    14
# Train_cost  = 21.9773 | Test_cost  = 23.3538 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    15
# Train_cost  = 20.7201 | Test_cost  = 22.0673 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    16
# Train_cost  = 19.7154 | Test_cost  = 21.0234 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    17
# Train_cost  = 18.9188 | Test_cost  = 20.1804 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    18
# Train_cost  = 18.2920 | Test_cost  = 19.5031 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    19
# Train_cost  = 17.8029 | Test_cost  = 18.9612 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    20
# Train_cost  = 17.4242 | Test_cost  = 18.5295 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    21
# Train_cost  = 17.1335 | Test_cost  = 18.1868 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    22
# Train_cost  = 16.9121 | Test_cost  = 17.9155 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    23
# Train_cost  = 16.7446 | Test_cost  = 17.7012 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    24
# Train_cost  = 16.6187 | Test_cost  = 17.5320 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    25
# Train_cost  = 16.5247 | Test_cost  = 17.3986 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    26
# Train_cost  = 16.4547 | Test_cost  = 17.2932 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    27
# Train_cost  = 16.4028 | Test_cost  = 17.2100 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    28
# Train_cost  = 16.3642 | Test_cost  = 17.1440 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    29
# Train_cost  = 16.3354 | Test_cost  = 17.0915 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    30
# Train_cost  = 16.3138 | Test_cost  = 17.0497 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    31
# Train_cost  = 16.2973 | Test_cost  = 17.0162 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    32
# Train_cost  = 16.2846 | Test_cost  = 16.9892 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    33
# Train_cost  = 16.2744 | Test_cost  = 16.9674 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    34
# Train_cost  = 16.2662 | Test_cost  = 16.9496 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    35
# Train_cost  = 16.2592 | Test_cost  = 16.9350 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    36
# Train_cost  = 16.2532 | Test_cost  = 16.9230 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    37
# Train_cost  = 16.2478 | Test_cost  = 16.9129 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    38
# Train_cost  = 16.2428 | Test_cost  = 16.9045 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    39
# Train_cost  = 16.2382 | Test_cost  = 16.8973 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    40
# Train_cost  = 16.2337 | Test_cost  = 16.8912 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    41
# Train_cost  = 16.2295 | Test_cost  = 16.8858 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    42
# Train_cost  = 16.2253 | Test_cost  = 16.8811 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    43
# Train_cost  = 16.2211 | Test_cost  = 16.8768 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    44
# Train_cost  = 16.2170 | Test_cost  = 16.8729 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    45
# Train_cost  = 16.2129 | Test_cost  = 16.8693 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    46
# Train_cost  = 16.2088 | Test_cost  = 16.8659 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    47
# Train_cost  = 16.2046 | Test_cost  = 16.8627 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    48
# Train_cost  = 16.2005 | Test_cost  = 16.8597 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    49
# Train_cost  = 16.1963 | Test_cost  = 16.8567 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    50
# Train_cost  = 16.1920 | Test_cost  = 16.8538 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    51
# Train_cost  = 16.1877 | Test_cost  = 16.8510 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    52
# Train_cost  = 16.1834 | Test_cost  = 16.8483 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    53
# Train_cost  = 16.1790 | Test_cost  = 16.8456 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    54
# Train_cost  = 16.1744 | Test_cost  = 16.8429 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    55
# Train_cost  = 16.1698 | Test_cost  = 16.8402 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    56
# Train_cost  = 16.1651 | Test_cost  = 16.8376 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    57
# Train_cost  = 16.1603 | Test_cost  = 16.8349 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    58
# Train_cost  = 16.1552 | Test_cost  = 16.8322 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    59
# Train_cost  = 16.1500 | Test_cost  = 16.8295 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    60
# Train_cost  = 16.1445 | Test_cost  = 16.8268 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    61
# Train_cost  = 16.1388 | Test_cost  = 16.8241 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    62
# Train_cost  = 16.1327 | Test_cost  = 16.8212 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    63
# Train_cost  = 16.1261 | Test_cost  = 16.8183 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    64
# Train_cost  = 16.1190 | Test_cost  = 16.8151 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    65
# Train_cost  = 16.1112 | Test_cost  = 16.8117 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    66
# Train_cost  = 16.1024 | Test_cost  = 16.8080 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    67
# Train_cost  = 16.0923 | Test_cost  = 16.8038 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    68
# Train_cost  = 16.0804 | Test_cost  = 16.7986 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    69
# Train_cost  = 16.0656 | Test_cost  = 16.7919 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    70
# Train_cost  = 16.0458 | Test_cost  = 16.7816 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    71
# Train_cost  = 16.0162 | Test_cost  = 16.7623 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    72
# Train_cost  = 15.9625 | Test_cost  = 16.7101 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    73
# Train_cost  = 15.8205 | Test_cost  = 16.4418 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    74
# Train_cost  = 14.9273 | Test_cost  = 14.9877 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    75
# Train_cost  = 13.5369 | Test_cost  = 13.9294 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    76
# Train_cost  = 12.6366 | Test_cost  = 12.6221 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    77
# Train_cost  = 11.7492 | Test_cost  = 11.7421 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    78
# Train_cost  = 11.0221 | Test_cost  = 11.0459 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    79
# Train_cost  = 10.5156 | Test_cost  = 10.3118 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    80
# Train_cost  = 9.9948 | Test_cost  = 9.7442 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    81
# Train_cost  = 9.5661 | Test_cost  = 9.2732 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    82
# Train_cost  = 9.2343 | Test_cost  = 8.8479 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    83
# Train_cost  = 8.9384 | Test_cost  = 8.4811 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    84
# Train_cost  = 8.6615 | Test_cost  = 8.1718 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    85
# Train_cost  = 8.4212 | Test_cost  = 7.9071 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    86
# Train_cost  = 8.2216 | Test_cost  = 7.6783 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    87
# Train_cost  = 8.0525 | Test_cost  = 7.4774 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    88
# Train_cost  = 7.9023 | Test_cost  = 7.2998 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    89
# Train_cost  = 7.7651 | Test_cost  = 7.1429 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    90
# Train_cost  = 7.6403 | Test_cost  = 7.0045 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    91
# Train_cost  = 7.5289 | Test_cost  = 6.8821 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    92
# Train_cost  = 7.4311 | Test_cost  = 6.7733 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    93
# Train_cost  = 7.3455 | Test_cost  = 6.6758 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    94
# Train_cost  = 7.2697 | Test_cost  = 6.5874 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    95
# Train_cost  = 7.2017 | Test_cost  = 6.5064 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    96
# Train_cost  = 7.1399 | Test_cost  = 6.4316 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    97
# Train_cost  = 7.0833 | Test_cost  = 6.3624 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    98
# Train_cost  = 7.0312 | Test_cost  = 6.2981 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch    99
# Train_cost  = 6.9830 | Test_cost  = 6.2382 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   100
# Train_cost  = 6.9384 | Test_cost  = 6.1825 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   101
# Train_cost  = 6.8969 | Test_cost  = 6.1305 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   102
# Train_cost  = 6.8583 | Test_cost  = 6.0820 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   103
# Train_cost  = 6.8222 | Test_cost  = 6.0365 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   104
# Train_cost  = 6.7882 | Test_cost  = 5.9938 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   105
# Train_cost  = 6.7562 | Test_cost  = 5.9534 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   106
# Train_cost  = 6.7257 | Test_cost  = 5.9152 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   107
# Train_cost  = 6.6966 | Test_cost  = 5.8788 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   108
# Train_cost  = 6.6688 | Test_cost  = 5.8441 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   109
# Train_cost  = 6.6420 | Test_cost  = 5.8110 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   110
# Train_cost  = 6.6165 | Test_cost  = 5.7795 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   111
# Train_cost  = 6.5922 | Test_cost  = 5.7496 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   112
# Train_cost  = 6.5691 | Test_cost  = 5.7212 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   113
# Train_cost  = 6.5473 | Test_cost  = 5.6942 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   114
# Train_cost  = 6.5267 | Test_cost  = 5.6686 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   115
# Train_cost  = 6.5072 | Test_cost  = 5.6442 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   116
# Train_cost  = 6.4887 | Test_cost  = 5.6209 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   117
# Train_cost  = 6.4710 | Test_cost  = 5.5986 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   118
# Train_cost  = 6.4542 | Test_cost  = 5.5772 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   119
# Train_cost  = 6.4382 | Test_cost  = 5.5568 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   120
# Train_cost  = 6.4228 | Test_cost  = 5.5373 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   121
# Train_cost  = 6.4081 | Test_cost  = 5.5186 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   122
# Train_cost  = 6.3940 | Test_cost  = 5.5008 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   123
# Train_cost  = 6.3804 | Test_cost  = 5.4838 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   124
# Train_cost  = 6.3674 | Test_cost  = 5.4676 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   125
# Train_cost  = 6.3549 | Test_cost  = 5.4521 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   126
# Train_cost  = 6.3430 | Test_cost  = 5.4374 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   127
# Train_cost  = 6.3315 | Test_cost  = 5.4233 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   128
# Train_cost  = 6.3204 | Test_cost  = 5.4099 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   129
# Train_cost  = 6.3099 | Test_cost  = 5.3971 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   130
# Train_cost  = 6.2997 | Test_cost  = 5.3848 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   131
# Train_cost  = 6.2899 | Test_cost  = 5.3731 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   132
# Train_cost  = 6.2804 | Test_cost  = 5.3619 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   133
# Train_cost  = 6.2712 | Test_cost  = 5.3511 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   134
# Train_cost  = 6.2623 | Test_cost  = 5.3408 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   135
# Train_cost  = 6.2536 | Test_cost  = 5.3309 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   136
# Train_cost  = 6.2452 | Test_cost  = 5.3214 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   137
# Train_cost  = 6.2369 | Test_cost  = 5.3123 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   138
# Train_cost  = 6.2288 | Test_cost  = 5.3035 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   139
# Train_cost  = 6.2208 | Test_cost  = 5.2951 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   140
# Train_cost  = 6.2130 | Test_cost  = 5.2871 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   141
# Train_cost  = 6.2053 | Test_cost  = 5.2793 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   142
# Train_cost  = 6.1977 | Test_cost  = 5.2719 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   143
# Train_cost  = 6.1903 | Test_cost  = 5.2647 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   144
# Train_cost  = 6.1829 | Test_cost  = 5.2578 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   145
# Train_cost  = 6.1756 | Test_cost  = 5.2512 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   146
# Train_cost  = 6.1684 | Test_cost  = 5.2449 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   147
# Train_cost  = 6.1614 | Test_cost  = 5.2389 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   148
# Train_cost  = 6.1544 | Test_cost  = 5.2331 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   149
# Train_cost  = 6.1475 | Test_cost  = 5.2276 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   150
# Train_cost  = 6.1408 | Test_cost  = 5.2224 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   151
# Train_cost  = 6.1341 | Test_cost  = 5.2174 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   152
# Train_cost  = 6.1276 | Test_cost  = 5.2127 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   153
# Train_cost  = 6.1212 | Test_cost  = 5.2083 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   154
# Train_cost  = 6.1148 | Test_cost  = 5.2041 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   155
# Train_cost  = 6.1086 | Test_cost  = 5.2002 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   156
# Train_cost  = 6.1025 | Test_cost  = 5.1966 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   157
# Train_cost  = 6.0965 | Test_cost  = 5.1933 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   158
# Train_cost  = 6.0906 | Test_cost  = 5.1903 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   159
# Train_cost  = 6.0848 | Test_cost  = 5.1875 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   160
# Train_cost  = 6.0791 | Test_cost  = 5.1851 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   161
# Train_cost  = 6.0735 | Test_cost  = 5.1829 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   162
# Train_cost  = 6.0679 | Test_cost  = 5.1810 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   163
# Train_cost  = 6.0624 | Test_cost  = 5.1793 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   164
# Train_cost  = 6.0569 | Test_cost  = 5.1780 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   165
# Train_cost  = 6.0515 | Test_cost  = 5.1769 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   166
# Train_cost  = 6.0462 | Test_cost  = 5.1760 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   167
# Train_cost  = 6.0408 | Test_cost  = 5.1754 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   168
# Train_cost  = 6.0355 | Test_cost  = 5.1750 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   169
# Train_cost  = 6.0302 | Test_cost  = 5.1749 |
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   170
# Train_cost  = 6.0249 | Test_cost  = 5.1749 |
# ==> EarlyStop patience =  1 | Best test_cost: 5.1749
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   171
# Train_cost  = 6.0196 | Test_cost  = 5.1751 |
# ==> EarlyStop patience =  2 | Best test_cost: 5.1749
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   172
# Train_cost  = 6.0143 | Test_cost  = 5.1754 |
# ==> EarlyStop patience =  3 | Best test_cost: 5.1749
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   173
# Train_cost  = 6.0090 | Test_cost  = 5.1759 |
# ==> EarlyStop patience =  4 | Best test_cost: 5.1749
# HBox(children=(FloatProgress(value=0.0, description='Train', max=7.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Test', max=2.0, style=ProgressStyle(description_width='in…
# Epoch   174
# Train_cost  = 6.0036 | Test_cost  = 5.1764 |
# ==> EarlyStop patience =  5 | Best test_cost: 5.1749
# ==> Execute Early Stopping at epoch: 174 | Best test_cost: 5.1749
# ==> Best model is saved at model/gru

# %% [markdown]
# # Sanity Check

# %%
from luwiji.rnn import illustration

# %%
illustration.forecast

# %%
from utils import data4pred, pred4pred

# %%
train_forecast_set =TimeSeriesDataset(ts_train,"Temp",1)
trainforecastloader = DataLoader(train_forecast_set)
test_forecast_set =TimeSeriesDataset(ts_test,"Temp",1)
testforecastloader = DataLoader(test_forecast_set)
# Out:
# (N, S, F): (2919, 1, 1)
# Note: last 0 data excluded
#
# (N, S, F): (729, 1, 1)
# Note: last 0 data excluded

# %% [markdown]
# # Visualization

# %%
#data 4 pred
plt.figure(figsize=(15,10))

plt.subplot(211)
data4pred(model,train_forecast_set, trainforecastloader, device)
plt.title("Train")

plt.subplot(212)
data4pred(model,test_forecast_set, testforecastloader, device)
plt.title("Test")
# Out:
# Text(0.5, 1.0, 'Test')

# %%
#pred 4 pred
plt.figure(figsize=(15,10))
pred4pred(model,test_forecast_set, testforecastloader, device)
plt.title("Test")
# Out:
# Text(0.5, 1.0, 'Test')
