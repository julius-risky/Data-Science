# %%
import pandas as pd

# %%
df =pd.read_csv('data_science/Assessment_Statistics_foundation_ Dataset_superstore_simple.csv')

# %%
df.head()
# Out:
#          order_id  order_date customer_id    segment         category  \
# 0  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164

# %%
df.dtypes
# Out:
# order_id         object
# order_date       object
# customer_id      object
# segment          object
# category         object
# sub_category     object
# sales           float64
# quantity          int64
# profit          float64
# dtype: object

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
order_ids=['CA-2016-152156','CA-2016-152156','CA-2016-138688','US-2015-108966','US-2015-108966']
couriers=['JNE','JNE',None,'J&T','J&T']

df_kurir=pd.DataFrame({
    'order_id':order_ids,
    'courier':couriers
})
df_kurir.head()
# Out:
#          order_id courier
# 0  CA-2016-152156     JNE
# 1  CA-2016-152156     JNE
# 2  CA-2016-138688    None
# 3  US-2015-108966     J&T
# 4  US-2015-108966     J&T

# %%
#mengecek misiing value
df_kurir.isna()
# Out:
#    order_id  courier
# 0     False    False
# 1     False    False
# 2     False     True
# 3     False    False
# 4     False    False

# %%
df_kurir.isna().any('columns')
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
df_kurir[df_kurir.isna().any('columns')]
# Out:
#          order_id courier
# 2  CA-2016-138688    None

# %%
df_kurir.to_csv('data_science/Dataset_superstore_kurir.csv')

# %%
df_kurir.to_csv('data_science/Dataset_superstore_kurir.csv',index=False)

# %%
#menggambungkan 2 data frame
df_head=df.head()

# %%
df_tail=df.tail()

# %%
df_head
# Out:
#          order_id  order_date customer_id    segment         category  \
# 0  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164

# %%
df_tail
# Out:
#             order_id  order_date customer_id   segment         category  \
# 9983  CA-2014-110422  2014-01-21    TB-21400  Consumer        Furniture
# 9984  CA-2017-121258  2017-02-26    DB-13060  Consumer        Furniture
# 9985  CA-2017-121258  2017-02-26    DB-13060  Consumer       Technology
# 9986  CA-2017-121258  2017-02-26    DB-13060  Consumer  Office Supplies
# 9987  CA-2017-119914  2017-05-04    CC-12220  Consumer  Office Supplies
#
#      sub_category    sales  quantity   profit
# 9983  Furnishings   25.248         3   4.1028
# 9984  Furnishings   91.960         2  15.6332
# 9985       Phones  258.576         2  19.3932
# 9986        Paper   29.600         4  13.3200
# 9987   Appliances  243.160         2  72.9480

# %%
df_concat=pd.concat([df_head,df_tail])

# %%
df_concat
# Out:
#             order_id  order_date customer_id    segment         category  \
# 0     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1     CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2     CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3     US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4     US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# 9983  CA-2014-110422  2014-01-21    TB-21400   Consumer        Furniture
# 9984  CA-2017-121258  2017-02-26    DB-13060   Consumer        Furniture
# 9985  CA-2017-121258  2017-02-26    DB-13060   Consumer       Technology
# 9986  CA-2017-121258  2017-02-26    DB-13060   Consumer  Office Supplies
# 9987  CA-2017-119914  2017-05-04    CC-12220   Consumer  Office Supplies
#
#      sub_category     sales  quantity    profit
# 0       Bookcases  261.9600         2   41.9136
# 1          Chairs  731.9400         3  219.5820
# ...

# %%
df_concat=pd.concat([df_head,df_tail],ignore_index=True)
df_concat
# Out:
#          order_id  order_date customer_id    segment         category  \
# 0  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# 5  CA-2014-110422  2014-01-21    TB-21400   Consumer        Furniture
# 6  CA-2017-121258  2017-02-26    DB-13060   Consumer        Furniture
# 7  CA-2017-121258  2017-02-26    DB-13060   Consumer       Technology
# 8  CA-2017-121258  2017-02-26    DB-13060   Consumer  Office Supplies
# 9  CA-2017-119914  2017-05-04    CC-12220   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# ...

# %%
df_concat.sort_values('order_date')
# Out:
#          order_id  order_date customer_id    segment         category  \
# 5  CA-2014-110422  2014-01-21    TB-21400   Consumer        Furniture
# 3  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# 2  CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 0  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 6  CA-2017-121258  2017-02-26    DB-13060   Consumer        Furniture
# 7  CA-2017-121258  2017-02-26    DB-13060   Consumer       Technology
# 8  CA-2017-121258  2017-02-26    DB-13060   Consumer  Office Supplies
# 9  CA-2017-119914  2017-05-04    CC-12220   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 5  Furnishings   25.2480         3    4.1028
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164
# ...

# %%
df_concat.sort_values('order_date',ascending=False)
# Out:
#          order_id  order_date customer_id    segment         category  \
# 9  CA-2017-119914  2017-05-04    CC-12220   Consumer  Office Supplies
# 6  CA-2017-121258  2017-02-26    DB-13060   Consumer        Furniture
# 7  CA-2017-121258  2017-02-26    DB-13060   Consumer       Technology
# 8  CA-2017-121258  2017-02-26    DB-13060   Consumer  Office Supplies
# 0  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# 5  CA-2014-110422  2014-01-21    TB-21400   Consumer        Furniture
#
#   sub_category     sales  quantity    profit
# 9   Appliances  243.1600         2   72.9480
# 6  Furnishings   91.9600         2   15.6332
# 7       Phones  258.5760         2   19.3932
# ...

# %%
df_concat=df_concat.sort_values('order_date',ascending=False)
df_concat
# Out:
#          order_id  order_date customer_id    segment         category  \
# 9  CA-2017-119914  2017-05-04    CC-12220   Consumer  Office Supplies
# 6  CA-2017-121258  2017-02-26    DB-13060   Consumer        Furniture
# 7  CA-2017-121258  2017-02-26    DB-13060   Consumer       Technology
# 8  CA-2017-121258  2017-02-26    DB-13060   Consumer  Office Supplies
# 0  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# 5  CA-2014-110422  2014-01-21    TB-21400   Consumer        Furniture
#
#   sub_category     sales  quantity    profit
# 9   Appliances  243.1600         2   72.9480
# 6  Furnishings   91.9600         2   15.6332
# 7       Phones  258.5760         2   19.3932
# ...

# %%
#merge 2 data frame
df_head=df.iloc[2:7]
df_head
# Out:
#          order_id  order_date customer_id    segment         category  \
# 2  CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# 5  CA-2014-115812  2014-06-09    BH-11710   Consumer        Furniture
# 6  CA-2014-115812  2014-06-09    BH-11710   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164
# 5  Furnishings   48.8600         7   14.1694
# 6          Art    7.2800         4    1.9656

# %%
df_kurir
df_merge = pd.merge(df_head,df_kurir, how='left',on='order_id')

# %%
df_merge
# Out:
#          order_id  order_date customer_id    segment         category  \
# 0  CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 1  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 2  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 3  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# 4  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
# 5  CA-2014-115812  2014-06-09    BH-11710   Consumer        Furniture
# 6  CA-2014-115812  2014-06-09    BH-11710   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit courier
# 0       Labels   14.6200         2    6.8714    None
# 1       Tables  957.5775         5 -383.0310     J&T
# 2       Tables  957.5775         5 -383.0310     J&T
# 3      Storage   22.3680         2    2.5164     J&T
# 4      Storage   22.3680         2    2.5164     J&T
# 5  Furnishings   48.8600         7   14.1694     NaN
# ...

# %%
#menghilangkan collom
df_merge.drop(columns=['customer_id','segment'])
# Out:
#          order_id  order_date         category sub_category     sales  \
# 0  CA-2016-138688  2016-06-12  Office Supplies       Labels   14.6200
# 1  US-2015-108966  2015-10-11        Furniture       Tables  957.5775
# 2  US-2015-108966  2015-10-11        Furniture       Tables  957.5775
# 3  US-2015-108966  2015-10-11  Office Supplies      Storage   22.3680
# 4  US-2015-108966  2015-10-11  Office Supplies      Storage   22.3680
# 5  CA-2014-115812  2014-06-09        Furniture  Furnishings   48.8600
# 6  CA-2014-115812  2014-06-09  Office Supplies          Art    7.2800
#
#    quantity    profit courier
# 0         2    6.8714    None
# 1         5 -383.0310     J&T
# 2         5 -383.0310     J&T
# 3         2    2.5164     J&T
# 4         2    2.5164     J&T
# 5         7   14.1694     NaN
# 6         4    1.9656     NaN

# %%
df_merge[['order_date','category','courier']]
# Out:
#    order_date         category courier
# 0  2016-06-12  Office Supplies    None
# 1  2015-10-11        Furniture     J&T
# 2  2015-10-11        Furniture     J&T
# 3  2015-10-11  Office Supplies     J&T
# 4  2015-10-11  Office Supplies     J&T
# 5  2014-06-09        Furniture     NaN
# 6  2014-06-09  Office Supplies     NaN

# %%
df_groupby=df.groupby(['order_date','category']).agg({'sales':'sum',})
df_groupby
# Out:
#                                sales
# order_date category
# 2014-01-03 Office Supplies    16.448
# 2014-01-04 Office Supplies   288.060
# 2014-01-05 Office Supplies    19.536
# 2014-01-06 Furniture        2573.820
#            Office Supplies   685.340
# ...                              ...
# 2017-12-29 Office Supplies   282.440
#            Technology        302.376
# 2017-12-30 Furniture         323.136
#            Office Supplies   299.724
#            Technology         90.930
#
# [2859 rows x 1 columns]

# %%
df.head()
# Out:
#          order_id  order_date customer_id    segment         category  \
# 0  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156  2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688  2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966  2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966  2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit
# 0    Bookcases  261.9600         2   41.9136
# 1       Chairs  731.9400         3  219.5820
# 2       Labels   14.6200         2    6.8714
# 3       Tables  957.5775         5 -383.0310
# 4      Storage   22.3680         2    2.5164

# %%
df['order_month']=df.order_date.dt.strftime('%Y-%m')

# %%
df.head()
# Out:
#          order_id order_date customer_id    segment         category  \
# 0  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 1  CA-2016-152156 2016-11-08    CG-12520   Consumer        Furniture
# 2  CA-2016-138688 2016-06-12    DV-13045  Corporate  Office Supplies
# 3  US-2015-108966 2015-10-11    SO-20335   Consumer        Furniture
# 4  US-2015-108966 2015-10-11    SO-20335   Consumer  Office Supplies
#
#   sub_category     sales  quantity    profit order_month
# 0    Bookcases  261.9600         2   41.9136     2016-11
# 1       Chairs  731.9400         3  219.5820     2016-11
# 2       Labels   14.6200         2    6.8714     2016-06
# 3       Tables  957.5775         5 -383.0310     2015-10
# 4      Storage   22.3680         2    2.5164     2015-10

# %%
df_groupby=df.groupby(['order_month','category']).agg({'sales':'sum',})
df_groupby
# Out:
#                                   sales
# order_month category
# 2014-01     Furniture         6242.5250
#             Office Supplies   4851.0800
#             Technology        3143.2900
# 2014-02     Furniture         1839.6580
#             Office Supplies   1071.7240
# ...                                 ...
# 2017-11     Office Supplies  31472.3370
#             Technology       39418.8030
# 2017-12     Furniture        31407.4668
#             Office Supplies  30436.9420
#             Technology       21984.9100
#
# [144 rows x 1 columns]

# %%
df_groupby=df_groupby.reset_index()
df_groupby
# Out:
#     order_month         category       sales
# 0       2014-01        Furniture   6242.5250
# 1       2014-01  Office Supplies   4851.0800
# 2       2014-01       Technology   3143.2900
# 3       2014-02        Furniture   1839.6580
# 4       2014-02  Office Supplies   1071.7240
# ..          ...              ...         ...
# 139     2017-11  Office Supplies  31472.3370
# 140     2017-11       Technology  39418.8030
# 141     2017-12        Furniture  31407.4668
# 142     2017-12  Office Supplies  30436.9420
# 143     2017-12       Technology  21984.9100
#
# [144 rows x 3 columns]

# %%
df_groupby=df_groupby.rename(columns={
    'order_month':'bulan'
})
df_groupby
# Out:
#        bulan         category       sales
# 0    2014-01        Furniture   6242.5250
# 1    2014-01  Office Supplies   4851.0800
# 2    2014-01       Technology   3143.2900
# 3    2014-02        Furniture   1839.6580
# 4    2014-02  Office Supplies   1071.7240
# ..       ...              ...         ...
# 139  2017-11  Office Supplies  31472.3370
# 140  2017-11       Technology  39418.8030
# 141  2017-12        Furniture  31407.4668
# 142  2017-12  Office Supplies  30436.9420
# 143  2017-12       Technology  21984.9100
#
# [144 rows x 3 columns]

# %%
df_groupby.pivot(index='bulan',columns='category',values='sales')
# Out:
# category   Furniture  Office Supplies  Technology
# bulan
# 2014-01    6242.5250         4851.080    3143.290
# 2014-02    1839.6580         1071.724    1608.510
# 2014-03   14573.9560         8605.879    9872.694
# 2014-04    7944.8370        11155.074    9195.434
# 2014-05    6912.7870         7135.624    9599.876
# 2014-06   13206.1256        12953.037    8435.965
# 2014-07   10821.0510        15121.208    8004.134
# 2014-08    7320.3465        11379.462    9209.660
# 2014-09   23816.4808        27423.298   30537.572
# 2014-10   12304.2470         7211.128   11938.018
# 2014-11   21564.8727        26862.436   30201.408
# 2014-12   30645.9665        18006.462   20893.192
# 2015-01   11739.9416         1808.780    4625.354
# 2015-02    3134.3740         5368.067    3448.970
# 2015-03   12499.7830        15882.547   10343.922
# 2015-04   10475.6985        12558.558   11160.952
# 2015-05    9374.9505         9113.736   11643.000
# 2015-06    7714.1790        10647.747    6435.366
# ...
